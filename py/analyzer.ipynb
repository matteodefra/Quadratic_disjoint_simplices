# %%
import pandas as pd
import os, sys

# %%
# path = "../results/rule1/n1000/K100"
# dirs = os.listdir(path)

# for file in dirs:
#     # if "step=2" in file:
#         print('rule 1')
#         print(file)
#         df = pd.read_csv(path + "/" + file)

#         print(f"Total iterations: {df.shape}\n")

#         print(f"Total time: {df['Time'].sum()}\n")
        
#         min_index = df.loc[df['Dual_gap'] > 0, 'Dual_gap'].idxmin()

#         print(f"Best dual gap: {df.loc[min_index, 'Dual_gap']}\n")
#         print(f"Best dual value: {df.loc[min_index, 'DualValue']}\n")
#         print(f"Best iteration: {df.loc[min_index, 'Iteration']}\n")
#         print(f"Best \lambda-norm: {df.loc[min_index, 'λ_norm_residual']}\n")
#         print(f"Best x-norm: {df.loc[min_index, 'x_norm_residual']}\n")

path = "../results/rule2/n1000/K100"
dirs = os.listdir(path)

for file in dirs:
    print('rule 2')
    print(file)
    df = pd.read_csv(path + "/" + file)

    print(f"Total iterations: {df.shape}\n")

    print(f"Total time: {df['Time'].sum()}\n")
    
    min_index = df.loc[df['Dual_gap'] > 0, 'Dual_gap'].idxmin()

    print(f"Best dual gap: {df.loc[min_index, 'Dual_gap']}\n")
    print(f"Best dual value: {df.loc[min_index, 'DualValue']}\n")
    print(f"Best iteration: {df.loc[min_index, 'Iteration']}\n")
    print(f"Best \lambda-norm: {df.loc[min_index, 'λ_norm_residual']}\n")
    print(f"Best x-norm: {df.loc[min_index, 'x_norm_residual']}\n")

path = "../results/rule3/n1000/K100"
dirs = os.listdir(path)

for file in dirs:
    # if "step=1" in file:
        print('rule 3')
        print(file)
        df = pd.read_csv(path + "/" + file)

        print(f"Total iterations: {df.shape}\n")

        print(f"Total time: {df['Time'].sum()}\n")
        
        min_index = df.loc[df['Dual_gap'] > 0, 'Dual_gap'].idxmin()

        print(f"Best dual gap: {df.loc[min_index, 'Dual_gap']}\n")
        print(f"Best dual value: {df.loc[min_index, 'DualValue']}\n")
        print(f"Best iteration: {df.loc[min_index, 'Iteration']}\n")
        print(f"Best \lambda-norm: {df.loc[min_index, 'λ_norm_residual']}\n")
        print(f"Best x-norm: {df.loc[min_index, 'x_norm_residual']}\n")
# Out:
# rule 2
# results_n=1000_K=100_update=2_delta=1e-8_h=1e6_step=1.csv
# Total iterations: (25000, 8)
#
# Total time: 173.5375986099231
#
# Best dual gap: 0.0082734881726388
#
# Best dual value: 2350520.316854967
#
# Best iteration: 23955
#
# Best \lambda-norm: 8880.263173258318
#
# Best x-norm: 583.7114649101475
#
# rule 2
# results_n=1000_K=100_update=2_delta=1e-16_alpha=1e5_step=3.csv
# Total iterations: (25000, 8)
#
# Total time: 164.0135154724109
#
# Best dual gap: 0.185892712110748
#
# Best dual value: 1935702.5773101468
#
# Best iteration: 25000
#
# Best \lambda-norm: 0.181522553336746
#
# Best x-norm: 0.0008910144592681
#
# rule 2
# results_n=1000_K=100_update=2_delta=1_h=1e2_step=0.csv
# Total iterations: (25000, 8)
#
# Total time: 227.44616580009338
#
# Best dual gap: 7.829963679143345e-06
#
# Best dual value: 2368624.339049019
#
# Best iteration: 25000
#
# Best \lambda-norm: 0.003418154163557
#
# Best x-norm: 4.498754904216048e-06
#
# rule 2
# ...

# %%
# path = "../results/rule1/n5000/K1000"
# dirs = os.listdir(path)

# for file in dirs:
#     if "step=0" in file:
#         print('rule 1')
#         print(file)
#         df = pd.read_csv(path + "/" + file)

#         print(f"Total iterations: {df.shape}\n")

#         print(f"Total time: {df['Time'].sum()}\n")
        
#         min_index = df.loc[df['Dual_gap'] > 0, 'Dual_gap'].idxmin()

#         print(f"Best dual gap: {df.loc[min_index, 'Dual_gap']}\n")
#         print(f"Best dual value: {df.loc[min_index, 'DualValue']}\n")
#         print(f"Best iteration: {df.loc[min_index, 'Iteration']}\n")
#         print(f"Best \lambda-norm: {df.loc[min_index, 'λ_norm_residual']}\n")
#         print(f"Best x-norm: {df.loc[min_index, 'x_norm_residual']}\n")

path = "../results/rule2/n5000/K1000"
dirs = os.listdir(path)

for file in dirs:
    if "step=0" in file:
        print('rule 2')
        print(file)
        df = pd.read_csv(path + "/" + file)

        print(f"Total iterations: {df.shape}\n")

        print(f"Total time: {df['Time'].sum()}\n")
        
        min_index = df.loc[df['Dual_gap'] > 0, 'Dual_gap'].idxmin()

        print(f"Best dual gap: {df.loc[min_index, 'Dual_gap']}\n")
        print(f"Best dual value: {df.loc[min_index, 'DualValue']}\n")
        print(f"Best iteration: {df.loc[min_index, 'Iteration']}\n")
        print(f"Best \lambda-norm: {df.loc[min_index, 'λ_norm_residual']}\n")
        print(f"Best x-norm: {df.loc[min_index, 'x_norm_residual']}\n")

# path = "../results/rule3/n5000/K1000"
# dirs = os.listdir(path)

# for file in dirs:
#     if "step=0" in file:
#         print('rule 3')
#         print(file)
#         df = pd.read_csv(path + "/" + file)

#         print(f"Total iterations: {df.shape}\n")

#         print(f"Total time: {df['Time'].sum()}\n")
        
#         min_index = df.loc[df['Dual_gap'] > 0, 'Dual_gap'].idxmin()

#         print(f"Best dual gap: {df.loc[min_index, 'Dual_gap']}\n")
#         print(f"Best dual value: {df.loc[min_index, 'DualValue']}\n")
#         print(f"Best iteration: {df.loc[min_index, 'Iteration']}\n")
#         print(f"Best \lambda-norm: {df.loc[min_index, 'λ_norm_residual']}\n")
#         print(f"Best x-norm: {df.loc[min_index, 'x_norm_residual']}\n")
# Out:
# rule 2
# results_n=5000_K=1000_update=2_delta=1e-16_h=1e4_step=0.csv
# Total iterations: (8547, 8)
#
# Total time: 451.23851656913723
#
# Best dual gap: 9.999196134115064e-07
#
# Best dual value: 1226851854.683607
#
# Best iteration: 8547
#
# Best \lambda-norm: 71.29224888301053
#
# Best x-norm: 6.0781034226221164

# %%
# path = "../results/rule1/n5000/K2500"
# dirs = os.listdir(path)

for file in dirs:
    if "step=4" in file:
        print('rule 1')
        print(file)
        df = pd.read_csv(path + "/" + file)

        print(f"Total iterations: {df.shape}\n")

        print(f"Total time: {df['Time'].sum()}\n")
        
        min_index = df.loc[df['Dual_gap'] > 0, 'Dual_gap'].idxmin()

        print(f"Best dual gap: {df.loc[min_index, 'Dual_gap']}\n")
        print(f"Best dual value: {df.loc[min_index, 'DualValue']}\n")
        print(f"Best iteration: {df.loc[min_index, 'Iteration']}\n")
        print(f"Best \lambda-norm: {df.loc[min_index, 'λ_norm_residual']}\n")
        print(f"Best x-norm: {df.loc[min_index, 'x_norm_residual']}\n")

# path = "../results/rule2/n5000/K2500"
# dirs = os.listdir(path)

# for file in dirs:
#     if ("step=0" or "step=1") in file:
#         print('rule 2')
#         print(file)
#         df = pd.read_csv(path + "/" + file)

#         print(f"Total iterations: {df.shape}\n")

#         print(f"Total time: {df['Time'].sum()}\n")
        
#         min_index = df.loc[df['Dual_gap'] > 0, 'Dual_gap'].idxmin()

#         print(f"Best dual gap: {df.loc[min_index, 'Dual_gap']}\n")
#         print(f"Best dual value: {df.loc[min_index, 'DualValue']}\n")
#         print(f"Best iteration: {df.loc[min_index, 'Iteration']}\n")
#         print(f"Best \lambda-norm: {df.loc[min_index, 'λ_norm_residual']}\n")
#         print(f"Best x-norm: {df.loc[min_index, 'x_norm_residual']}\n")

# path = "../results/rule3/n5000/K2500"
# dirs = os.listdir(path)

# for file in dirs:
#     if "step=1" in file:
#         print('rule 3')
#         print(file)
#         df = pd.read_csv(path + "/" + file)

#         print(f"Total iterations: {df.shape}\n")

#         print(f"Total time: {df['Time'].sum()}\n")
        
#         min_index = df.loc[df['Dual_gap'] > 0, 'Dual_gap'].idxmin()

#         print(f"Best dual gap: {df.loc[min_index, 'Dual_gap']}\n")
#         print(f"Best dual value: {df.loc[min_index, 'DualValue']}\n")
#         print(f"Best iteration: {df.loc[min_index, 'Iteration']}\n")
#         print(f"Best \lambda-norm: {df.loc[min_index, 'λ_norm_residual']}\n")
#         print(f"Best x-norm: {df.loc[min_index, 'x_norm_residual']}\n")
# Out:
# rule 1
# results_n=5000_K=2500_update=3_delta=1e-16_poliak_step=4.csv
# Total iterations: (10000, 8)
#
# Total time: 709.1215398311613
#
# Best dual gap: 0.0285581500138876
#
# Best dual value: 7537166099.289713
#
# Best iteration: 10000
#
# Best \lambda-norm: 100.036780748277
#
# Best x-norm: 0.0661612892744822
